# %%
# %matplotlib inline

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import sklearn.preprocessing as sp
from scipy import stats

# %%
Dataset = np.load('Dataset.npy')

# %%
Dataset = np.random.permutation(Dataset)

X_train = Dataset[:8000,:9]
Y_train = Dataset[:8000,-3:]
X_test  = Dataset[8000:,:9]
Y_test  = Dataset[8000:,-3:]

def Standardization(Data):
    scaler = sp.StandardScaler().fit(Data)
    scl = scaler.transform(Data)
    return scl , scaler

X_train_scl = Standardization(X_train)[0]
X_test_scl = Standardization(X_test)[0]
Y_train_scl = Standardization(Y_train)[0]
Y_test_scl = Standardization(Y_test)[0]

np.save('X_train.npy' , X_train)
np.save('X_train_scl.npy' , X_train_scl)

# %%
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units = 16 , activation = 'relu' , input_dim = 9) ,
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.Dense(units = 3                       )
        ])

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
              loss = 'mse',
              metrics = ['accuracy','mse'])
model.summary()
history = model.fit(X_train_scl , Y_train_scl , epochs = 300 , batch_size = 800 , validation_split = 0.2 , verbose = 0)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                160
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 51
# =================================================================
# Total params: 1,299
# Trainable params: 1,299
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.save('Final_model.h5')

# %%
score = model.evaluate(X_test_scl , Y_test_scl , batch_size = 1000 , verbose = 0)
print('score:',score)
print('Accuracy:',score[1]*100,'%')
# Out:
# score: [0.0017164300011938754, 0.984565, 0.00171643]
# Accuracy: 98.4565019607544 %

# %%
Y_train_stdev = Standardization(Y_train)[1].scale_
Y_train_mean  = Standardization(Y_train)[1].mean_

np.save('Y_train_stdev.npy' , Y_train_stdev)
np.save('Y_train_mean.npy' , Y_train_mean)

Y_predict_scl = model.predict(X_test_scl)
Y_predict = Y_predict_scl * Y_train_stdev + Y_train_mean

# %%
plt.figure(dpi = 150)
plt.title('Train & Validation Accuracy')
plt.plot(history.history['accuracy'],label = 'Train_Accuracy')
plt.plot(history.history['val_accuracy'],label = 'Validation_Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0,1)
#plt.savefig('Accuracy.png', dpi = 150)
# Out:
# (0.0, 1.0)

# %%
plt.figure(dpi = 150)
plt.title('Train & Validation MSE')
plt.plot(history.history['mse'],label = 'Train')
plt.plot(history.history['val_mse'],label = 'Validation')
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.legend()
#plt.savefig('MSE', dpi = 150)

# %%
Y_test_reshape = np.reshape(Y_test[:,0],(2138,))
Y_predict_reshape = np.reshape(Y_predict[:,0],(2138,))
R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])

min = 0.0
max = 0.8
plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,0],Y_predict[:,0],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real XME_V')
plt.ylabel('Predict XME_V')
plt.savefig('XME_V.png', dpi = 150)
# Out:
# R_Pearson =  0.9986198378856468

# %%
Y_test_reshape = np.reshape(Y_test[:,1],(2138,))
Y_predict_reshape = np.reshape(Y_predict[:,1],(2138,))
R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])

min = 0.8
max = 1.0
plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,1],Y_predict[:,1],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real XME_D')
plt.ylabel('Predict XME_D')
plt.savefig('XME_D.png', dpi = 150)
# Out:
# R_Pearson =  0.9998198577298805

# %%
Y_test_reshape = np.reshape(Y_test[:,2],(2138,))
Y_predict_reshape = np.reshape(Y_predict[:,2],(2138,))

min = 0.8
max = 1.0
plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,2],Y_predict[:,2],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real XW_B')
plt.ylabel('Predict XW_B')
plt.savefig('XW_B.png', dpi = 150)

R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])
# Out:
# R_Pearson =  0.9998071362229539

# %%
axis = 0.05
error = (Y_predict[:,0] - Y_test[:,0])
plt.figure(dpi = 150)
plt.hist(error, bins = 500)
plt.xlabel("Prediction Error XME_V")
plt.ylabel("Count")
plt.xlim(-axis,axis)
plt.savefig('Error XME_V.png', dpi = 150)

# %%
axis = 0.05
error = (Y_predict[:,1] - Y_test[:,1])
plt.figure(dpi = 150)
plt.hist(error , bins = 500)
plt.xlabel("Prediction Error XME_D")
plt.ylabel("Count")
plt.xlim(-axis,axis)
plt.savefig('Error XME_D.png', dpi = 150)

# %%
axis = 0.05
error = (Y_predict[:,2] - Y_test[:,2])
plt.figure(dpi = 150)
plt.hist(error , bins = 1000)
plt.xlabel("Prediction Error XW_B")
plt.ylabel("Count")
plt.xlim(-axis,axis)
plt.savefig('Error XW_B.png', dpi = 150)

# %%
'''
Tin = input('Tin = ')
FR = input('FR = ')
T1 = input('T1 = ')
T2 = input('T2 = ')
Qcool = input('Qcool = ')
RR = input('RR = ')
B = input('B = ')
QR = input('QR')
Qc = input('Qc')
X_real = np.array([Tin , FR , T1 , T2 , Qcool , RR , B , QR , Qc])
X_train = np.vstack([X_train,X_real])

scaler_X_train = sp.StandardScaler().fit(X_train)
X_train_scl = scaler_X_train.transform(X_train)

Y_predict_scl = model.predict(X_train_scl)
Y_predict = Y_predict_scl * scaler_Y_train.scale_ + scaler_Y_train.mean_

X_real = X_train[-1,:]
Y_real = Y_predict[-1,:]
print(X_real)
print(Y_real)
'''
# Out:
# "\nTin = input('Tin = ')\nFR = input('FR = ')\nT1 = input('T1 = ')\nT2 = input('T2 = ')\nQcool = input('Qcool = ')\nRR = input('RR = ')\nB = input('B = ')\nQR = input('QR')\nQc = input('Qc')\nX_real = np.array([Tin , FR , T1 , T2 , Qcool , RR , B , QR , Qc])\nX_train = np.vstack([X_train,X_real])\n\nscaler_X_train = sp.StandardScaler().fit(X_train)\nX_train_scl = scaler_X_train.transform(X_train)\n\nY_predict_scl = model.predict(X_train_scl)\nY_predict = Y_predict_scl * scaler_Y_train.scale_ + scaler_Y_train.mean_\n\nX_real = X_train[-1,:]\nY_real = Y_predict[-1,:]\nprint(X_real)\nprint(Y_real)\n"
