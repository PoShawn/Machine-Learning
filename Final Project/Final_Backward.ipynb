# %%
# %matplotlib inline

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import sklearn.preprocessing as sp
from scipy import stats

# %%
Dataset_raw = pd.read_csv('Final_Data.csv')

# %%
Dataset_df = Dataset_raw[['Tin','FR','T1','T2','Qcool','RR','B','QR','Qc','FV','FL_Top','FL_Bot','T5','T10','T15','T20','T25','XME_V','XME_D','XW_B']]

# %%
Dataset_df
# Out:
#          Tin    FR    T1    T2       Qcool    RR        B          QR  \
# 0      230.3  5.01  46.9  47.3 -3408.57514  1.37   99.750  1983.48465
# 1      230.1  4.99  47.1  47.1 -3361.39142  1.35   99.780  1915.60558
# 2      230.2  4.96  47.0  47.3 -3381.69240  1.32   99.750  1904.54513
# 3      230.1  4.96  46.9  47.2 -3386.32257  1.34   99.750  1931.66436
# 4      230.1  4.96  47.0  47.0 -3373.49223  1.32   99.750  1897.66426
# ...      ...   ...   ...   ...         ...   ...      ...         ...
# 15932  238.7  4.66  57.0  43.5 -2778.68173  2.57  101.975  2466.88934
# 15933  238.4  4.69  57.3  43.8 -2733.54212  2.59  101.950  2443.71320
# 15934  238.7  4.66  57.4  44.2 -2741.43180  2.60  101.930  2457.44303
# 15935  239.1  4.65  57.9  44.2 -2719.76161  2.56  101.955  2386.51443
# 15936  239.2  4.68  58.3  44.5 -2691.05823  2.59  101.945  2385.60385
#
#                Qc        FV     FL_Top     FL_Bot         T5        T10  \
# 0     -2488.67285  1.138522  98.280150  64.914011  66.257027  69.541474
# 1     -2468.84306  1.115023  98.296869  64.923862  66.300389  69.675587
# 2     -2435.46282  1.142253  98.255017  64.936598  66.353072  69.789407
# 3     -2457.12858  1.138654  98.259095  64.926414  66.312165  69.688798
# 4     -2437.68179  1.116335  98.291160  64.936477  66.353103  69.794478
# ...           ...       ...        ...        ...        ...        ...
# 15932 -3715.32348  0.543364  96.821734  64.859134  65.779825  67.830652
# 15933 -3737.10741  0.545191  96.911121  64.859891  65.779871  67.832493
# 15934 -3746.68840  0.564553  96.964680  64.859930  65.779101  67.825150
# 15935 -3701.16486  0.549742  96.874197  64.860486  65.784184  67.867261
# 15936 -3734.87679  0.548801  97.005825  64.861386  65.783099  67.857135
#
#              T15        T20        T25     XME_V     XME_D      XW_B
# 0      75.486573  76.672814  87.675879  0.494652  0.995920  0.993144
# 1      75.673650  76.848653  87.632430  0.490251  0.995804  0.992883
# 2      75.703274  76.876799  87.627191  0.494556  0.995726  0.992843
# 3      75.625758  76.797898  87.520617  0.492412  0.995789  0.992799
# 4      75.723243  76.896943  87.658595  0.488026  0.995669  0.992860
# ...          ...        ...        ...       ...       ...       ...
# 15932  74.295629  75.245604  80.543126  0.417377  0.996010  0.973971
# 15933  74.344810  75.296630  80.659625  0.423115  0.996075  0.974561
# 15934  74.321131  75.275515  80.697085  0.430865  0.996145  0.974983
# 15935  74.457235  75.406400  80.734354  0.430865  0.996151  0.974436
# 15936  74.464077  75.415954  80.817246  0.436758  0.996218  0.975013
#
# [15937 rows x 20 columns]

# %%
#Dataset_df.info()

# %%
#Dataset_df.isnull().sum()

# %%
#Dataset_df.corr()

# %%
'''
sns.set(rc = {'figure.figsize':(25,15)})
sns.heatmap(Dataset_df.corr().round(2), annot=True, linewidths=0.2, square=True)
'''
# Out:
# "\nsns.set(rc = {'figure.figsize':(25,15)})\nsns.heatmap(Dataset_df.corr().round(2), annot=True, linewidths=0.2, square=True)\n"

# %%
Dataset_raw = np.array(Dataset_df)
Dataset = np.random.permutation(Dataset_raw)

FR = Dataset[:,1:2]
RR = Dataset[:,5:6]
B  = Dataset[:,6:7]
QR = Dataset[:,7:8]
Y  = np.hstack([RR,B,QR])

X_train = Dataset[:12000,-11:]
Y_train = Y[:12000,:]
X_test  = Dataset[12000:,-11:]
Y_test  = Y[12000:,:]

scaler_X_train = sp.StandardScaler().fit(X_train)
X_train_scl = scaler_X_train.transform(X_train)
scaler_X_test = sp.StandardScaler().fit(X_test)
X_test_scl = scaler_X_test.transform(X_test)
scaler_Y_train = sp.StandardScaler().fit(Y_train)
Y_train_scl = scaler_Y_train.transform(Y_train)
scaler_Y_test = sp.StandardScaler().fit(Y_test)
Y_test_scl = scaler_Y_test.transform(Y_test)

# %%
'''
model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units = 16 , activation = 'relu' , input_dim = 11) ,
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'relu'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 3                        )
        ])
'''

model = tf.keras.models.Sequential([
        tf.keras.layers.Dense(units = 16 , activation = 'tanh' , input_dim = 11) ,
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 16 , activation = 'tanh'),
        tf.keras.layers.BatchNormalization(axis = 1),
        tf.keras.layers.Dense(units = 3                        )
        ])

model.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.01),
              loss = 'mse',
              metrics = ['accuracy','mse'])
model.summary()
history = model.fit(X_train_scl , Y_train_scl , epochs = 250 , batch_size = 1000 , validation_split = 0.2 , verbose = 2)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 16)                64
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16)                64
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16)                64
# _________________________________________________________________
# dense_3 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 16)                64
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 16)                64
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 16)                64
# _________________________________________________________________
# dense_6 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 16)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 16)                64
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 16)                64
# _________________________________________________________________
# dense_9 (Dense)              (None, 16)                272
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 16)                64
# _________________________________________________________________
# dense_10 (Dense)             (None, 16)                272
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 16)                64
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                272
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 16)                64
# _________________________________________________________________
# dense_12 (Dense)             (None, 16)                272
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 16)                64
# _________________________________________________________________
# dense_13 (Dense)             (None, 16)                272
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 16)                64
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                272
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 16)                64
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 51
# =================================================================
# Total params: 5,011
# Trainable params: 4,531
# Non-trainable params: 480
# _________________________________________________________________
# Train on 9600 samples, validate on 2400 samples
# Epoch 1/250
# 9600/9600 - 6s - loss: 0.6443 - accuracy: 0.4625 - mse: 0.6443 - val_loss: 0.4100 - val_accuracy: 0.3929 - val_mse: 0.4100
# Epoch 2/250
# 9600/9600 - 1s - loss: 0.1116 - accuracy: 0.5994 - mse: 0.1116 - val_loss: 0.2884 - val_accuracy: 0.4271 - val_mse: 0.2884
# Epoch 3/250
# 9600/9600 - 1s - loss: 0.0756 - accuracy: 0.6523 - mse: 0.0756 - val_loss: 0.2606 - val_accuracy: 0.4187 - val_mse: 0.2606
# Epoch 4/250
# 9600/9600 - 1s - loss: 0.0570 - accuracy: 0.7042 - mse: 0.0570 - val_loss: 0.2742 - val_accuracy: 0.4563 - val_mse: 0.2742
# Epoch 5/250
# 9600/9600 - 1s - loss: 0.0491 - accuracy: 0.7545 - mse: 0.0491 - val_loss: 0.2927 - val_accuracy: 0.4596 - val_mse: 0.2927
# Epoch 6/250
# 9600/9600 - 1s - loss: 0.0430 - accuracy: 0.7805 - mse: 0.0430 - val_loss: 0.3073 - val_accuracy: 0.6092 - val_mse: 0.3073
# Epoch 7/250
# 9600/9600 - 1s - loss: 0.0390 - accuracy: 0.7874 - mse: 0.0390 - val_loss: 0.3231 - val_accuracy: 0.5458 - val_mse: 0.3231
# Epoch 8/250
# 9600/9600 - 1s - loss: 0.0344 - accuracy: 0.8105 - mse: 0.0344 - val_loss: 0.3545 - val_accuracy: 0.6204 - val_mse: 0.3545
# Epoch 9/250
# 9600/9600 - 1s - loss: 0.0299 - accuracy: 0.8195 - mse: 0.0299 - val_loss: 0.3609 - val_accuracy: 0.5308 - val_mse: 0.3609
# Epoch 10/250
# 9600/9600 - 1s - loss: 0.0284 - accuracy: 0.8130 - mse: 0.0284 - val_loss: 0.3315 - val_accuracy: 0.5108 - val_mse: 0.3315
# Epoch 11/250
# 9600/9600 - 1s - loss: 0.0264 - accuracy: 0.8259 - mse: 0.0264 - val_loss: 0.3123 - val_accuracy: 0.5300 - val_mse: 0.3123
# Epoch 12/250
# 9600/9600 - 1s - loss: 0.0258 - accuracy: 0.8216 - mse: 0.0258 - val_loss: 0.2944 - val_accuracy: 0.5871 - val_mse: 0.2944
# Epoch 13/250
# 9600/9600 - 1s - loss: 0.0240 - accuracy: 0.8348 - mse: 0.0240 - val_loss: 0.2795 - val_accuracy: 0.6121 - val_mse: 0.2795
# Epoch 14/250
# 9600/9600 - 1s - loss: 0.0229 - accuracy: 0.8352 - mse: 0.0229 - val_loss: 0.2611 - val_accuracy: 0.6675 - val_mse: 0.2611
# Epoch 15/250
# 9600/9600 - 1s - loss: 0.0243 - accuracy: 0.8340 - mse: 0.0243 - val_loss: 0.2470 - val_accuracy: 0.6938 - val_mse: 0.2470
# Epoch 16/250
# 9600/9600 - 1s - loss: 0.0223 - accuracy: 0.8411 - mse: 0.0223 - val_loss: 0.2425 - val_accuracy: 0.6333 - val_mse: 0.2425
# Epoch 17/250
# 9600/9600 - 1s - loss: 0.0202 - accuracy: 0.8499 - mse: 0.0202 - val_loss: 0.2246 - val_accuracy: 0.6454 - val_mse: 0.2246
# Epoch 18/250
# 9600/9600 - 1s - loss: 0.0182 - accuracy: 0.8501 - mse: 0.0182 - val_loss: 0.2032 - val_accuracy: 0.6667 - val_mse: 0.2032
# Epoch 19/250
# 9600/9600 - 1s - loss: 0.0195 - accuracy: 0.8660 - mse: 0.0195 - val_loss: 0.2138 - val_accuracy: 0.7108 - val_mse: 0.2138
# Epoch 20/250
# 9600/9600 - 1s - loss: 0.0178 - accuracy: 0.8597 - mse: 0.0178 - val_loss: 0.1822 - val_accuracy: 0.6771 - val_mse: 0.1822
# Epoch 21/250
# 9600/9600 - 1s - loss: 0.0184 - accuracy: 0.8658 - mse: 0.0184 - val_loss: 0.1604 - val_accuracy: 0.6808 - val_mse: 0.1604
# Epoch 22/250
# 9600/9600 - 1s - loss: 0.0182 - accuracy: 0.8661 - mse: 0.0182 - val_loss: 0.1657 - val_accuracy: 0.6392 - val_mse: 0.1657
# Epoch 23/250
# 9600/9600 - 1s - loss: 0.0155 - accuracy: 0.8673 - mse: 0.0155 - val_loss: 0.1477 - val_accuracy: 0.6850 - val_mse: 0.1477
# Epoch 24/250
# 9600/9600 - 1s - loss: 0.0175 - accuracy: 0.8641 - mse: 0.0175 - val_loss: 0.1525 - val_accuracy: 0.7175 - val_mse: 0.1525
# Epoch 25/250
# 9600/9600 - 1s - loss: 0.0150 - accuracy: 0.8796 - mse: 0.0150 - val_loss: 0.1305 - val_accuracy: 0.7146 - val_mse: 0.1305
# Epoch 26/250
# 9600/9600 - 1s - loss: 0.0166 - accuracy: 0.8736 - mse: 0.0166 - val_loss: 0.1200 - val_accuracy: 0.7371 - val_mse: 0.1200
# Epoch 27/250
# 9600/9600 - 1s - loss: 0.0148 - accuracy: 0.8790 - mse: 0.0148 - val_loss: 0.0899 - val_accuracy: 0.7004 - val_mse: 0.0899
# Epoch 28/250
# 9600/9600 - 1s - loss: 0.0187 - accuracy: 0.8826 - mse: 0.0187 - val_loss: 0.1250 - val_accuracy: 0.7321 - val_mse: 0.1250
# Epoch 29/250
# 9600/9600 - 1s - loss: 0.0146 - accuracy: 0.8849 - mse: 0.0146 - val_loss: 0.1759 - val_accuracy: 0.7504 - val_mse: 0.1759
# Epoch 30/250
# 9600/9600 - 1s - loss: 0.0166 - accuracy: 0.8843 - mse: 0.0166 - val_loss: 0.1159 - val_accuracy: 0.7412 - val_mse: 0.1159
# Epoch 31/250
# 9600/9600 - 1s - loss: 0.0173 - accuracy: 0.8511 - mse: 0.0173 - val_loss: 0.1000 - val_accuracy: 0.7600 - val_mse: 0.1000
# Epoch 32/250
# 9600/9600 - 1s - loss: 0.0144 - accuracy: 0.8777 - mse: 0.0144 - val_loss: 0.1004 - val_accuracy: 0.6750 - val_mse: 0.1004
# Epoch 33/250
# 9600/9600 - 1s - loss: 0.0158 - accuracy: 0.8736 - mse: 0.0158 - val_loss: 0.0871 - val_accuracy: 0.7704 - val_mse: 0.0871
# Epoch 34/250
# 9600/9600 - 1s - loss: 0.0134 - accuracy: 0.8794 - mse: 0.0134 - val_loss: 0.0971 - val_accuracy: 0.7321 - val_mse: 0.0971
# Epoch 35/250
# 9600/9600 - 1s - loss: 0.0140 - accuracy: 0.8935 - mse: 0.0140 - val_loss: 0.1445 - val_accuracy: 0.7479 - val_mse: 0.1445
# Epoch 36/250
# 9600/9600 - 1s - loss: 0.0195 - accuracy: 0.8596 - mse: 0.0195 - val_loss: 0.0443 - val_accuracy: 0.8379 - val_mse: 0.0443
# Epoch 37/250
# 9600/9600 - 1s - loss: 0.0163 - accuracy: 0.8816 - mse: 0.0163 - val_loss: 0.0428 - val_accuracy: 0.7933 - val_mse: 0.0428
# Epoch 38/250
# 9600/9600 - 1s - loss: 0.0118 - accuracy: 0.8894 - mse: 0.0118 - val_loss: 0.0571 - val_accuracy: 0.7675 - val_mse: 0.0571
# Epoch 39/250
# 9600/9600 - 1s - loss: 0.0136 - accuracy: 0.8986 - mse: 0.0136 - val_loss: 0.0752 - val_accuracy: 0.8004 - val_mse: 0.0752
# Epoch 40/250
# 9600/9600 - 1s - loss: 0.0123 - accuracy: 0.9054 - mse: 0.0123 - val_loss: 0.0495 - val_accuracy: 0.7867 - val_mse: 0.0495
# Epoch 41/250
# 9600/9600 - 1s - loss: 0.0126 - accuracy: 0.8979 - mse: 0.0126 - val_loss: 0.0329 - val_accuracy: 0.7983 - val_mse: 0.0329
# Epoch 42/250
# 9600/9600 - 1s - loss: 0.0095 - accuracy: 0.9034 - mse: 0.0095 - val_loss: 0.0401 - val_accuracy: 0.8379 - val_mse: 0.0401
# Epoch 43/250
# 9600/9600 - 1s - loss: 0.0115 - accuracy: 0.9093 - mse: 0.0115 - val_loss: 0.0663 - val_accuracy: 0.7979 - val_mse: 0.0663
# Epoch 44/250
# 9600/9600 - 1s - loss: 0.0099 - accuracy: 0.9162 - mse: 0.0099 - val_loss: 0.0587 - val_accuracy: 0.7550 - val_mse: 0.0587
# Epoch 45/250
# 9600/9600 - 1s - loss: 0.0104 - accuracy: 0.9148 - mse: 0.0104 - val_loss: 0.0586 - val_accuracy: 0.7887 - val_mse: 0.0586
# Epoch 46/250
# 9600/9600 - 1s - loss: 0.0113 - accuracy: 0.9057 - mse: 0.0113 - val_loss: 0.0564 - val_accuracy: 0.7746 - val_mse: 0.0564
# Epoch 47/250
# 9600/9600 - 1s - loss: 0.0109 - accuracy: 0.9153 - mse: 0.0109 - val_loss: 0.0526 - val_accuracy: 0.8042 - val_mse: 0.0526
# Epoch 48/250
# 9600/9600 - 1s - loss: 0.0098 - accuracy: 0.9098 - mse: 0.0098 - val_loss: 0.0433 - val_accuracy: 0.7900 - val_mse: 0.0433
# Epoch 49/250
# 9600/9600 - 1s - loss: 0.0092 - accuracy: 0.9202 - mse: 0.0092 - val_loss: 0.0354 - val_accuracy: 0.8467 - val_mse: 0.0354
# Epoch 50/250
# 9600/9600 - 1s - loss: 0.0088 - accuracy: 0.9153 - mse: 0.0088 - val_loss: 0.0495 - val_accuracy: 0.8083 - val_mse: 0.0495
# Epoch 51/250
# 9600/9600 - 1s - loss: 0.0104 - accuracy: 0.9043 - mse: 0.0104 - val_loss: 0.0443 - val_accuracy: 0.7771 - val_mse: 0.0443
# Epoch 52/250
# 9600/9600 - 1s - loss: 0.0098 - accuracy: 0.9053 - mse: 0.0098 - val_loss: 0.0423 - val_accuracy: 0.8358 - val_mse: 0.0423
# Epoch 53/250
# 9600/9600 - 1s - loss: 0.0108 - accuracy: 0.9127 - mse: 0.0108 - val_loss: 0.0392 - val_accuracy: 0.8225 - val_mse: 0.0392
# Epoch 54/250
# 9600/9600 - 1s - loss: 0.0096 - accuracy: 0.9243 - mse: 0.0096 - val_loss: 0.0423 - val_accuracy: 0.8467 - val_mse: 0.0423
# Epoch 55/250
# 9600/9600 - 1s - loss: 0.0120 - accuracy: 0.9055 - mse: 0.0120 - val_loss: 0.0440 - val_accuracy: 0.8108 - val_mse: 0.0440
# Epoch 56/250
# 9600/9600 - 1s - loss: 0.0109 - accuracy: 0.9118 - mse: 0.0109 - val_loss: 0.0368 - val_accuracy: 0.8358 - val_mse: 0.0368
# Epoch 57/250
# 9600/9600 - 1s - loss: 0.0087 - accuracy: 0.9190 - mse: 0.0087 - val_loss: 0.0369 - val_accuracy: 0.8392 - val_mse: 0.0369
# Epoch 58/250
# 9600/9600 - 1s - loss: 0.0093 - accuracy: 0.9124 - mse: 0.0093 - val_loss: 0.0392 - val_accuracy: 0.8267 - val_mse: 0.0392
# Epoch 59/250
# 9600/9600 - 1s - loss: 0.0094 - accuracy: 0.9158 - mse: 0.0094 - val_loss: 0.0385 - val_accuracy: 0.8154 - val_mse: 0.0385
# Epoch 60/250
# 9600/9600 - 1s - loss: 0.0077 - accuracy: 0.9215 - mse: 0.0077 - val_loss: 0.0320 - val_accuracy: 0.8350 - val_mse: 0.0320
# Epoch 61/250
# 9600/9600 - 1s - loss: 0.0084 - accuracy: 0.9194 - mse: 0.0084 - val_loss: 0.0505 - val_accuracy: 0.8350 - val_mse: 0.0505
# Epoch 62/250
# 9600/9600 - 1s - loss: 0.0081 - accuracy: 0.9230 - mse: 0.0081 - val_loss: 0.0411 - val_accuracy: 0.8342 - val_mse: 0.0411
# Epoch 63/250
# 9600/9600 - 1s - loss: 0.0091 - accuracy: 0.9118 - mse: 0.0091 - val_loss: 0.0255 - val_accuracy: 0.8571 - val_mse: 0.0255
# Epoch 64/250
# 9600/9600 - 1s - loss: 0.0080 - accuracy: 0.9221 - mse: 0.0080 - val_loss: 0.0239 - val_accuracy: 0.8446 - val_mse: 0.0239
# Epoch 65/250
# 9600/9600 - 1s - loss: 0.0074 - accuracy: 0.9234 - mse: 0.0074 - val_loss: 0.0200 - val_accuracy: 0.8783 - val_mse: 0.0200
# Epoch 66/250
# 9600/9600 - 1s - loss: 0.0086 - accuracy: 0.9236 - mse: 0.0086 - val_loss: 0.0241 - val_accuracy: 0.8708 - val_mse: 0.0241
# Epoch 67/250
# 9600/9600 - 1s - loss: 0.0088 - accuracy: 0.9168 - mse: 0.0088 - val_loss: 0.0262 - val_accuracy: 0.8583 - val_mse: 0.0262
# Epoch 68/250
# 9600/9600 - 1s - loss: 0.0106 - accuracy: 0.9215 - mse: 0.0106 - val_loss: 0.0213 - val_accuracy: 0.9025 - val_mse: 0.0213
# Epoch 69/250
# 9600/9600 - 1s - loss: 0.0081 - accuracy: 0.9253 - mse: 0.0081 - val_loss: 0.0236 - val_accuracy: 0.9146 - val_mse: 0.0236
# Epoch 70/250
# 9600/9600 - 1s - loss: 0.0094 - accuracy: 0.9121 - mse: 0.0094 - val_loss: 0.0224 - val_accuracy: 0.8721 - val_mse: 0.0224
# Epoch 71/250
# 9600/9600 - 1s - loss: 0.0081 - accuracy: 0.9278 - mse: 0.0081 - val_loss: 0.0182 - val_accuracy: 0.8771 - val_mse: 0.0182
# Epoch 72/250
# 9600/9600 - 1s - loss: 0.0076 - accuracy: 0.9286 - mse: 0.0076 - val_loss: 0.0206 - val_accuracy: 0.8996 - val_mse: 0.0206
# Epoch 73/250
# 9600/9600 - 1s - loss: 0.0071 - accuracy: 0.9214 - mse: 0.0071 - val_loss: 0.0210 - val_accuracy: 0.8471 - val_mse: 0.0210
# Epoch 74/250
# 9600/9600 - 1s - loss: 0.0072 - accuracy: 0.9275 - mse: 0.0072 - val_loss: 0.0195 - val_accuracy: 0.8571 - val_mse: 0.0195
# Epoch 75/250
# 9600/9600 - 1s - loss: 0.0073 - accuracy: 0.9245 - mse: 0.0073 - val_loss: 0.0193 - val_accuracy: 0.8367 - val_mse: 0.0193
# Epoch 76/250
# 9600/9600 - 1s - loss: 0.0083 - accuracy: 0.9080 - mse: 0.0083 - val_loss: 0.0198 - val_accuracy: 0.8388 - val_mse: 0.0198
# Epoch 77/250
# 9600/9600 - 1s - loss: 0.0111 - accuracy: 0.9117 - mse: 0.0111 - val_loss: 0.0328 - val_accuracy: 0.8221 - val_mse: 0.0328
# Epoch 78/250
# 9600/9600 - 1s - loss: 0.0097 - accuracy: 0.9059 - mse: 0.0097 - val_loss: 0.0297 - val_accuracy: 0.8446 - val_mse: 0.0297
# Epoch 79/250
# 9600/9600 - 1s - loss: 0.0091 - accuracy: 0.9300 - mse: 0.0091 - val_loss: 0.0167 - val_accuracy: 0.8508 - val_mse: 0.0167
# Epoch 80/250
# 9600/9600 - 1s - loss: 0.0075 - accuracy: 0.9208 - mse: 0.0075 - val_loss: 0.0142 - val_accuracy: 0.8900 - val_mse: 0.0142
# Epoch 81/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9206 - mse: 0.0078 - val_loss: 0.0172 - val_accuracy: 0.8933 - val_mse: 0.0172
# Epoch 82/250
# 9600/9600 - 1s - loss: 0.0095 - accuracy: 0.9236 - mse: 0.0095 - val_loss: 0.0126 - val_accuracy: 0.8754 - val_mse: 0.0126
# Epoch 83/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9294 - mse: 0.0078 - val_loss: 0.0139 - val_accuracy: 0.8417 - val_mse: 0.0139
# Epoch 84/250
# 9600/9600 - 1s - loss: 0.0071 - accuracy: 0.9130 - mse: 0.0071 - val_loss: 0.0108 - val_accuracy: 0.8704 - val_mse: 0.0108
# Epoch 85/250
# 9600/9600 - 1s - loss: 0.0085 - accuracy: 0.9218 - mse: 0.0085 - val_loss: 0.0224 - val_accuracy: 0.8729 - val_mse: 0.0224
# Epoch 86/250
# 9600/9600 - 1s - loss: 0.0064 - accuracy: 0.9304 - mse: 0.0064 - val_loss: 0.0185 - val_accuracy: 0.8529 - val_mse: 0.0185
# Epoch 87/250
# 9600/9600 - 1s - loss: 0.0070 - accuracy: 0.9233 - mse: 0.0070 - val_loss: 0.0148 - val_accuracy: 0.8392 - val_mse: 0.0148
# Epoch 88/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9316 - mse: 0.0078 - val_loss: 0.0162 - val_accuracy: 0.9296 - val_mse: 0.0162
# Epoch 89/250
# 9600/9600 - 1s - loss: 0.0081 - accuracy: 0.9134 - mse: 0.0081 - val_loss: 0.0170 - val_accuracy: 0.9296 - val_mse: 0.0170
# Epoch 90/250
# 9600/9600 - 1s - loss: 0.0075 - accuracy: 0.9323 - mse: 0.0075 - val_loss: 0.0112 - val_accuracy: 0.8754 - val_mse: 0.0112
# Epoch 91/250
# 9600/9600 - 1s - loss: 0.0073 - accuracy: 0.9239 - mse: 0.0073 - val_loss: 0.0102 - val_accuracy: 0.8600 - val_mse: 0.0102
# Epoch 92/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9297 - mse: 0.0062 - val_loss: 0.0092 - val_accuracy: 0.9388 - val_mse: 0.0092
# Epoch 93/250
# 9600/9600 - 1s - loss: 0.0068 - accuracy: 0.9201 - mse: 0.0068 - val_loss: 0.0110 - val_accuracy: 0.9367 - val_mse: 0.0110
# Epoch 94/250
# 9600/9600 - 1s - loss: 0.0076 - accuracy: 0.9287 - mse: 0.0076 - val_loss: 0.0169 - val_accuracy: 0.9508 - val_mse: 0.0169
# Epoch 95/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9201 - mse: 0.0078 - val_loss: 0.0117 - val_accuracy: 0.8650 - val_mse: 0.0117
# Epoch 96/250
# 9600/9600 - 1s - loss: 0.0066 - accuracy: 0.9248 - mse: 0.0066 - val_loss: 0.0105 - val_accuracy: 0.9383 - val_mse: 0.0105
# Epoch 97/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9267 - mse: 0.0065 - val_loss: 0.0115 - val_accuracy: 0.8388 - val_mse: 0.0115
# Epoch 98/250
# 9600/9600 - 1s - loss: 0.0054 - accuracy: 0.9270 - mse: 0.0054 - val_loss: 0.0117 - val_accuracy: 0.8917 - val_mse: 0.0117
# Epoch 99/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9294 - mse: 0.0062 - val_loss: 0.0071 - val_accuracy: 0.8896 - val_mse: 0.0071
# Epoch 100/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9276 - mse: 0.0055 - val_loss: 0.0086 - val_accuracy: 0.9308 - val_mse: 0.0086
# Epoch 101/250
# 9600/9600 - 1s - loss: 0.0068 - accuracy: 0.9320 - mse: 0.0068 - val_loss: 0.0069 - val_accuracy: 0.9454 - val_mse: 0.0069
# Epoch 102/250
# 9600/9600 - 1s - loss: 0.0081 - accuracy: 0.9232 - mse: 0.0081 - val_loss: 0.0076 - val_accuracy: 0.9458 - val_mse: 0.0076
# Epoch 103/250
# 9600/9600 - 1s - loss: 0.0082 - accuracy: 0.9236 - mse: 0.0082 - val_loss: 0.0084 - val_accuracy: 0.9271 - val_mse: 0.0084
# Epoch 104/250
# 9600/9600 - 1s - loss: 0.0080 - accuracy: 0.9259 - mse: 0.0080 - val_loss: 0.0117 - val_accuracy: 0.9125 - val_mse: 0.0117
# Epoch 105/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9275 - mse: 0.0078 - val_loss: 0.0091 - val_accuracy: 0.8838 - val_mse: 0.0091
# Epoch 106/250
# 9600/9600 - 1s - loss: 0.0071 - accuracy: 0.9299 - mse: 0.0071 - val_loss: 0.0098 - val_accuracy: 0.9367 - val_mse: 0.0098
# Epoch 107/250
# 9600/9600 - 1s - loss: 0.0063 - accuracy: 0.9419 - mse: 0.0063 - val_loss: 0.0110 - val_accuracy: 0.9254 - val_mse: 0.0110
# Epoch 108/250
# 9600/9600 - 1s - loss: 0.0076 - accuracy: 0.9305 - mse: 0.0076 - val_loss: 0.0082 - val_accuracy: 0.9262 - val_mse: 0.0082
# Epoch 109/250
# 9600/9600 - 1s - loss: 0.0057 - accuracy: 0.9312 - mse: 0.0057 - val_loss: 0.0094 - val_accuracy: 0.9196 - val_mse: 0.0094
# Epoch 110/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9275 - mse: 0.0061 - val_loss: 0.0093 - val_accuracy: 0.9425 - val_mse: 0.0093
# Epoch 111/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9280 - mse: 0.0065 - val_loss: 0.0102 - val_accuracy: 0.8667 - val_mse: 0.0102
# Epoch 112/250
# 9600/9600 - 1s - loss: 0.0064 - accuracy: 0.9297 - mse: 0.0064 - val_loss: 0.0102 - val_accuracy: 0.8996 - val_mse: 0.0102
# Epoch 113/250
# 9600/9600 - 1s - loss: 0.0058 - accuracy: 0.9344 - mse: 0.0058 - val_loss: 0.0116 - val_accuracy: 0.8788 - val_mse: 0.0116
# Epoch 114/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9309 - mse: 0.0065 - val_loss: 0.0085 - val_accuracy: 0.9433 - val_mse: 0.0085
# Epoch 115/250
# 9600/9600 - 1s - loss: 0.0052 - accuracy: 0.9382 - mse: 0.0052 - val_loss: 0.0104 - val_accuracy: 0.8400 - val_mse: 0.0104
# Epoch 116/250
# 9600/9600 - 1s - loss: 0.0052 - accuracy: 0.9343 - mse: 0.0052 - val_loss: 0.0071 - val_accuracy: 0.8908 - val_mse: 0.0071
# Epoch 117/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9352 - mse: 0.0051 - val_loss: 0.0054 - val_accuracy: 0.9513 - val_mse: 0.0054
# Epoch 118/250
# 9600/9600 - 1s - loss: 0.0044 - accuracy: 0.9325 - mse: 0.0044 - val_loss: 0.0069 - val_accuracy: 0.9467 - val_mse: 0.0069
# Epoch 119/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9446 - mse: 0.0051 - val_loss: 0.0095 - val_accuracy: 0.9292 - val_mse: 0.0095
# Epoch 120/250
# 9600/9600 - 1s - loss: 0.0048 - accuracy: 0.9351 - mse: 0.0048 - val_loss: 0.0089 - val_accuracy: 0.9383 - val_mse: 0.0089
# Epoch 121/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9336 - mse: 0.0055 - val_loss: 0.0080 - val_accuracy: 0.9317 - val_mse: 0.0080
# Epoch 122/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9171 - mse: 0.0062 - val_loss: 0.0103 - val_accuracy: 0.9446 - val_mse: 0.0103
# Epoch 123/250
# 9600/9600 - 1s - loss: 0.0069 - accuracy: 0.9294 - mse: 0.0069 - val_loss: 0.0078 - val_accuracy: 0.9221 - val_mse: 0.0078
# Epoch 124/250
# 9600/9600 - 1s - loss: 0.0056 - accuracy: 0.9344 - mse: 0.0056 - val_loss: 0.0113 - val_accuracy: 0.9200 - val_mse: 0.0113
# Epoch 125/250
# 9600/9600 - 1s - loss: 0.0099 - accuracy: 0.9057 - mse: 0.0099 - val_loss: 0.0125 - val_accuracy: 0.8888 - val_mse: 0.0125
# Epoch 126/250
# 9600/9600 - 1s - loss: 0.0084 - accuracy: 0.9083 - mse: 0.0084 - val_loss: 0.0087 - val_accuracy: 0.8512 - val_mse: 0.0087
# Epoch 127/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9200 - mse: 0.0062 - val_loss: 0.0118 - val_accuracy: 0.8717 - val_mse: 0.0118
# Epoch 128/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9292 - mse: 0.0065 - val_loss: 0.0107 - val_accuracy: 0.8754 - val_mse: 0.0107
# Epoch 129/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9297 - mse: 0.0055 - val_loss: 0.0103 - val_accuracy: 0.8288 - val_mse: 0.0103
# Epoch 130/250
# 9600/9600 - 1s - loss: 0.0063 - accuracy: 0.9169 - mse: 0.0063 - val_loss: 0.0091 - val_accuracy: 0.9146 - val_mse: 0.0091
# Epoch 131/250
# 9600/9600 - 1s - loss: 0.0070 - accuracy: 0.9312 - mse: 0.0070 - val_loss: 0.0119 - val_accuracy: 0.8213 - val_mse: 0.0119
# Epoch 132/250
# 9600/9600 - 1s - loss: 0.0070 - accuracy: 0.9290 - mse: 0.0070 - val_loss: 0.0127 - val_accuracy: 0.8879 - val_mse: 0.0127
# Epoch 133/250
# 9600/9600 - 1s - loss: 0.0076 - accuracy: 0.9275 - mse: 0.0076 - val_loss: 0.0102 - val_accuracy: 0.8842 - val_mse: 0.0102
# Epoch 134/250
# 9600/9600 - 1s - loss: 0.0080 - accuracy: 0.9241 - mse: 0.0080 - val_loss: 0.0130 - val_accuracy: 0.9038 - val_mse: 0.0130
# Epoch 135/250
# 9600/9600 - 1s - loss: 0.0069 - accuracy: 0.9235 - mse: 0.0069 - val_loss: 0.0101 - val_accuracy: 0.9058 - val_mse: 0.0101
# Epoch 136/250
# 9600/9600 - 1s - loss: 0.0063 - accuracy: 0.9310 - mse: 0.0063 - val_loss: 0.0085 - val_accuracy: 0.9046 - val_mse: 0.0085
# Epoch 137/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9255 - mse: 0.0061 - val_loss: 0.0066 - val_accuracy: 0.9212 - val_mse: 0.0066
# Epoch 138/250
# 9600/9600 - 1s - loss: 0.0066 - accuracy: 0.9228 - mse: 0.0066 - val_loss: 0.0070 - val_accuracy: 0.8908 - val_mse: 0.0070
# Epoch 139/250
# 9600/9600 - 1s - loss: 0.0058 - accuracy: 0.9345 - mse: 0.0058 - val_loss: 0.0070 - val_accuracy: 0.9588 - val_mse: 0.0070
# Epoch 140/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9320 - mse: 0.0045 - val_loss: 0.0083 - val_accuracy: 0.9279 - val_mse: 0.0083
# Epoch 141/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9442 - mse: 0.0051 - val_loss: 0.0053 - val_accuracy: 0.9300 - val_mse: 0.0053
# Epoch 142/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9457 - mse: 0.0045 - val_loss: 0.0053 - val_accuracy: 0.9321 - val_mse: 0.0053
# Epoch 143/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9391 - mse: 0.0043 - val_loss: 0.0076 - val_accuracy: 0.8679 - val_mse: 0.0076
# Epoch 144/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9274 - mse: 0.0061 - val_loss: 0.0083 - val_accuracy: 0.9192 - val_mse: 0.0083
# Epoch 145/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9265 - mse: 0.0059 - val_loss: 0.0052 - val_accuracy: 0.9425 - val_mse: 0.0052
# Epoch 146/250
# 9600/9600 - 1s - loss: 0.0082 - accuracy: 0.9350 - mse: 0.0082 - val_loss: 0.0126 - val_accuracy: 0.8192 - val_mse: 0.0126
# Epoch 147/250
# 9600/9600 - 1s - loss: 0.0069 - accuracy: 0.8991 - mse: 0.0069 - val_loss: 0.0109 - val_accuracy: 0.9025 - val_mse: 0.0109
# Epoch 148/250
# 9600/9600 - 1s - loss: 0.0086 - accuracy: 0.9237 - mse: 0.0086 - val_loss: 0.0091 - val_accuracy: 0.9171 - val_mse: 0.0091
# Epoch 149/250
# 9600/9600 - 1s - loss: 0.0078 - accuracy: 0.9202 - mse: 0.0078 - val_loss: 0.0084 - val_accuracy: 0.9117 - val_mse: 0.0084
# Epoch 150/250
# 9600/9600 - 1s - loss: 0.0060 - accuracy: 0.9276 - mse: 0.0060 - val_loss: 0.0079 - val_accuracy: 0.9092 - val_mse: 0.0079
# Epoch 151/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9324 - mse: 0.0065 - val_loss: 0.0082 - val_accuracy: 0.8850 - val_mse: 0.0082
# Epoch 152/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9315 - mse: 0.0059 - val_loss: 0.0064 - val_accuracy: 0.9375 - val_mse: 0.0064
# Epoch 153/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9161 - mse: 0.0065 - val_loss: 0.0101 - val_accuracy: 0.9021 - val_mse: 0.0101
# Epoch 154/250
# 9600/9600 - 1s - loss: 0.0057 - accuracy: 0.9207 - mse: 0.0057 - val_loss: 0.0105 - val_accuracy: 0.9112 - val_mse: 0.0105
# Epoch 155/250
# 9600/9600 - 1s - loss: 0.0065 - accuracy: 0.9232 - mse: 0.0065 - val_loss: 0.0106 - val_accuracy: 0.8587 - val_mse: 0.0106
# Epoch 156/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9309 - mse: 0.0055 - val_loss: 0.0086 - val_accuracy: 0.9017 - val_mse: 0.0086
# Epoch 157/250
# 9600/9600 - 1s - loss: 0.0058 - accuracy: 0.9272 - mse: 0.0058 - val_loss: 0.0053 - val_accuracy: 0.9200 - val_mse: 0.0053
# Epoch 158/250
# 9600/9600 - 1s - loss: 0.0085 - accuracy: 0.9242 - mse: 0.0085 - val_loss: 0.0073 - val_accuracy: 0.8708 - val_mse: 0.0073
# Epoch 159/250
# 9600/9600 - 1s - loss: 0.0091 - accuracy: 0.9089 - mse: 0.0091 - val_loss: 0.0086 - val_accuracy: 0.8700 - val_mse: 0.0086
# Epoch 160/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9301 - mse: 0.0055 - val_loss: 0.0057 - val_accuracy: 0.9354 - val_mse: 0.0057
# Epoch 161/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9396 - mse: 0.0051 - val_loss: 0.0072 - val_accuracy: 0.8800 - val_mse: 0.0072
# Epoch 162/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9292 - mse: 0.0053 - val_loss: 0.0057 - val_accuracy: 0.9417 - val_mse: 0.0057
# Epoch 163/250
# 9600/9600 - 1s - loss: 0.0041 - accuracy: 0.9392 - mse: 0.0041 - val_loss: 0.0054 - val_accuracy: 0.9529 - val_mse: 0.0054
# Epoch 164/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9390 - mse: 0.0061 - val_loss: 0.0127 - val_accuracy: 0.8717 - val_mse: 0.0127
# Epoch 165/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9386 - mse: 0.0059 - val_loss: 0.0093 - val_accuracy: 0.9058 - val_mse: 0.0093
# Epoch 166/250
# 9600/9600 - 1s - loss: 0.0064 - accuracy: 0.9270 - mse: 0.0064 - val_loss: 0.0118 - val_accuracy: 0.8921 - val_mse: 0.0118
# Epoch 167/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9361 - mse: 0.0062 - val_loss: 0.0103 - val_accuracy: 0.8512 - val_mse: 0.0103
# Epoch 168/250
# 9600/9600 - 1s - loss: 0.0041 - accuracy: 0.9295 - mse: 0.0041 - val_loss: 0.0097 - val_accuracy: 0.8950 - val_mse: 0.0097
# Epoch 169/250
# 9600/9600 - 1s - loss: 0.0048 - accuracy: 0.9349 - mse: 0.0048 - val_loss: 0.0206 - val_accuracy: 0.7804 - val_mse: 0.0206
# Epoch 170/250
# 9600/9600 - 1s - loss: 0.0056 - accuracy: 0.9201 - mse: 0.0056 - val_loss: 0.0068 - val_accuracy: 0.8979 - val_mse: 0.0068
# Epoch 171/250
# 9600/9600 - 1s - loss: 0.0046 - accuracy: 0.9430 - mse: 0.0046 - val_loss: 0.0066 - val_accuracy: 0.9029 - val_mse: 0.0066
# Epoch 172/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9428 - mse: 0.0053 - val_loss: 0.0090 - val_accuracy: 0.8842 - val_mse: 0.0090
# Epoch 173/250
# 9600/9600 - 1s - loss: 0.0068 - accuracy: 0.9346 - mse: 0.0068 - val_loss: 0.0085 - val_accuracy: 0.8496 - val_mse: 0.0085
# Epoch 174/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9282 - mse: 0.0061 - val_loss: 0.0080 - val_accuracy: 0.9117 - val_mse: 0.0080
# Epoch 175/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9316 - mse: 0.0061 - val_loss: 0.0110 - val_accuracy: 0.8579 - val_mse: 0.0110
# Epoch 176/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9298 - mse: 0.0061 - val_loss: 0.0087 - val_accuracy: 0.9008 - val_mse: 0.0087
# Epoch 177/250
# 9600/9600 - 1s - loss: 0.0047 - accuracy: 0.9376 - mse: 0.0047 - val_loss: 0.0055 - val_accuracy: 0.9350 - val_mse: 0.0055
# Epoch 178/250
# 9600/9600 - 1s - loss: 0.0057 - accuracy: 0.9180 - mse: 0.0057 - val_loss: 0.0078 - val_accuracy: 0.8904 - val_mse: 0.0078
# Epoch 179/250
# 9600/9600 - 1s - loss: 0.0054 - accuracy: 0.9365 - mse: 0.0054 - val_loss: 0.0049 - val_accuracy: 0.9496 - val_mse: 0.0049
# Epoch 180/250
# 9600/9600 - 1s - loss: 0.0060 - accuracy: 0.9372 - mse: 0.0060 - val_loss: 0.0063 - val_accuracy: 0.9117 - val_mse: 0.0063
# Epoch 181/250
# 9600/9600 - 1s - loss: 0.0055 - accuracy: 0.9257 - mse: 0.0055 - val_loss: 0.0073 - val_accuracy: 0.8604 - val_mse: 0.0073
# Epoch 182/250
# 9600/9600 - 1s - loss: 0.0054 - accuracy: 0.9279 - mse: 0.0054 - val_loss: 0.0080 - val_accuracy: 0.9383 - val_mse: 0.0080
# Epoch 183/250
# 9600/9600 - 1s - loss: 0.0049 - accuracy: 0.9346 - mse: 0.0049 - val_loss: 0.0050 - val_accuracy: 0.9192 - val_mse: 0.0050
# Epoch 184/250
# 9600/9600 - 1s - loss: 0.0042 - accuracy: 0.9320 - mse: 0.0042 - val_loss: 0.0041 - val_accuracy: 0.9237 - val_mse: 0.0041
# Epoch 185/250
# 9600/9600 - 1s - loss: 0.0044 - accuracy: 0.9400 - mse: 0.0044 - val_loss: 0.0067 - val_accuracy: 0.8704 - val_mse: 0.0067
# Epoch 186/250
# 9600/9600 - 1s - loss: 0.0056 - accuracy: 0.9348 - mse: 0.0056 - val_loss: 0.0084 - val_accuracy: 0.8775 - val_mse: 0.0084
# Epoch 187/250
# 9600/9600 - 1s - loss: 0.0064 - accuracy: 0.9218 - mse: 0.0064 - val_loss: 0.0064 - val_accuracy: 0.9246 - val_mse: 0.0064
# Epoch 188/250
# 9600/9600 - 1s - loss: 0.0084 - accuracy: 0.9382 - mse: 0.0084 - val_loss: 0.0083 - val_accuracy: 0.8829 - val_mse: 0.0083
# Epoch 189/250
# 9600/9600 - 1s - loss: 0.0060 - accuracy: 0.9395 - mse: 0.0060 - val_loss: 0.0066 - val_accuracy: 0.9329 - val_mse: 0.0066
# Epoch 190/250
# 9600/9600 - 1s - loss: 0.0060 - accuracy: 0.9369 - mse: 0.0060 - val_loss: 0.0138 - val_accuracy: 0.8346 - val_mse: 0.0138
# Epoch 191/250
# 9600/9600 - 1s - loss: 0.0058 - accuracy: 0.9316 - mse: 0.0058 - val_loss: 0.0081 - val_accuracy: 0.9008 - val_mse: 0.0081
# Epoch 192/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9320 - mse: 0.0043 - val_loss: 0.0044 - val_accuracy: 0.9483 - val_mse: 0.0044
# Epoch 193/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9242 - mse: 0.0045 - val_loss: 0.0069 - val_accuracy: 0.9104 - val_mse: 0.0069
# Epoch 194/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9293 - mse: 0.0061 - val_loss: 0.0101 - val_accuracy: 0.8804 - val_mse: 0.0101
# Epoch 195/250
# 9600/9600 - 1s - loss: 0.0079 - accuracy: 0.9355 - mse: 0.0079 - val_loss: 0.0092 - val_accuracy: 0.8679 - val_mse: 0.0092
# Epoch 196/250
# 9600/9600 - 1s - loss: 0.0047 - accuracy: 0.9281 - mse: 0.0047 - val_loss: 0.0057 - val_accuracy: 0.9100 - val_mse: 0.0057
# Epoch 197/250
# 9600/9600 - 1s - loss: 0.0047 - accuracy: 0.9485 - mse: 0.0047 - val_loss: 0.0049 - val_accuracy: 0.9517 - val_mse: 0.0049
# Epoch 198/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9455 - mse: 0.0043 - val_loss: 0.0069 - val_accuracy: 0.9192 - val_mse: 0.0069
# Epoch 199/250
# 9600/9600 - 1s - loss: 0.0048 - accuracy: 0.9493 - mse: 0.0048 - val_loss: 0.0052 - val_accuracy: 0.9025 - val_mse: 0.0052
# Epoch 200/250
# 9600/9600 - 1s - loss: 0.0049 - accuracy: 0.9354 - mse: 0.0049 - val_loss: 0.0061 - val_accuracy: 0.9246 - val_mse: 0.0061
# Epoch 201/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9307 - mse: 0.0059 - val_loss: 0.0080 - val_accuracy: 0.8537 - val_mse: 0.0080
# Epoch 202/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9179 - mse: 0.0062 - val_loss: 0.0087 - val_accuracy: 0.9050 - val_mse: 0.0087
# Epoch 203/250
# 9600/9600 - 1s - loss: 0.0095 - accuracy: 0.9223 - mse: 0.0095 - val_loss: 0.0131 - val_accuracy: 0.8975 - val_mse: 0.0131
# Epoch 204/250
# 9600/9600 - 1s - loss: 0.0061 - accuracy: 0.9262 - mse: 0.0061 - val_loss: 0.0110 - val_accuracy: 0.8863 - val_mse: 0.0110
# Epoch 205/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9354 - mse: 0.0053 - val_loss: 0.0094 - val_accuracy: 0.9212 - val_mse: 0.0094
# Epoch 206/250
# 9600/9600 - 1s - loss: 0.0039 - accuracy: 0.9428 - mse: 0.0039 - val_loss: 0.0079 - val_accuracy: 0.9300 - val_mse: 0.0079
# Epoch 207/250
# 9600/9600 - 1s - loss: 0.0037 - accuracy: 0.9432 - mse: 0.0037 - val_loss: 0.0103 - val_accuracy: 0.9283 - val_mse: 0.0103
# Epoch 208/250
# 9600/9600 - 1s - loss: 0.0084 - accuracy: 0.9446 - mse: 0.0084 - val_loss: 0.0174 - val_accuracy: 0.8617 - val_mse: 0.0174
# Epoch 209/250
# 9600/9600 - 1s - loss: 0.0130 - accuracy: 0.9029 - mse: 0.0130 - val_loss: 0.0174 - val_accuracy: 0.9067 - val_mse: 0.0174
# Epoch 210/250
# 9600/9600 - 1s - loss: 0.0096 - accuracy: 0.9020 - mse: 0.0096 - val_loss: 0.0164 - val_accuracy: 0.8375 - val_mse: 0.0164
# Epoch 211/250
# 9600/9600 - 1s - loss: 0.0077 - accuracy: 0.9167 - mse: 0.0077 - val_loss: 0.0159 - val_accuracy: 0.8817 - val_mse: 0.0159
# Epoch 212/250
# 9600/9600 - 1s - loss: 0.0097 - accuracy: 0.9139 - mse: 0.0097 - val_loss: 0.0176 - val_accuracy: 0.8925 - val_mse: 0.0176
# Epoch 213/250
# 9600/9600 - 1s - loss: 0.0087 - accuracy: 0.9167 - mse: 0.0087 - val_loss: 0.0134 - val_accuracy: 0.8804 - val_mse: 0.0134
# Epoch 214/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9265 - mse: 0.0059 - val_loss: 0.0259 - val_accuracy: 0.8054 - val_mse: 0.0259
# Epoch 215/250
# 9600/9600 - 1s - loss: 0.0059 - accuracy: 0.9396 - mse: 0.0059 - val_loss: 0.0099 - val_accuracy: 0.8550 - val_mse: 0.0099
# Epoch 216/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9222 - mse: 0.0053 - val_loss: 0.0060 - val_accuracy: 0.9125 - val_mse: 0.0060
# Epoch 217/250
# 9600/9600 - 1s - loss: 0.0050 - accuracy: 0.9366 - mse: 0.0050 - val_loss: 0.0086 - val_accuracy: 0.9162 - val_mse: 0.0086
# Epoch 218/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9315 - mse: 0.0045 - val_loss: 0.0058 - val_accuracy: 0.8967 - val_mse: 0.0058
# Epoch 219/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9414 - mse: 0.0045 - val_loss: 0.0091 - val_accuracy: 0.8729 - val_mse: 0.0091
# Epoch 220/250
# 9600/9600 - 1s - loss: 0.0060 - accuracy: 0.9337 - mse: 0.0060 - val_loss: 0.0076 - val_accuracy: 0.9204 - val_mse: 0.0076
# Epoch 221/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9333 - mse: 0.0051 - val_loss: 0.0070 - val_accuracy: 0.8933 - val_mse: 0.0070
# Epoch 222/250
# 9600/9600 - 1s - loss: 0.0045 - accuracy: 0.9173 - mse: 0.0045 - val_loss: 0.0088 - val_accuracy: 0.9633 - val_mse: 0.0088
# Epoch 223/250
# 9600/9600 - 1s - loss: 0.0041 - accuracy: 0.9429 - mse: 0.0041 - val_loss: 0.0078 - val_accuracy: 0.8575 - val_mse: 0.0078
# Epoch 224/250
# 9600/9600 - 1s - loss: 0.0052 - accuracy: 0.9429 - mse: 0.0052 - val_loss: 0.0048 - val_accuracy: 0.9271 - val_mse: 0.0048
# Epoch 225/250
# 9600/9600 - 1s - loss: 0.0047 - accuracy: 0.9446 - mse: 0.0047 - val_loss: 0.0063 - val_accuracy: 0.9413 - val_mse: 0.0063
# Epoch 226/250
# 9600/9600 - 1s - loss: 0.0068 - accuracy: 0.9315 - mse: 0.0068 - val_loss: 0.0074 - val_accuracy: 0.9300 - val_mse: 0.0074
# Epoch 227/250
# 9600/9600 - 1s - loss: 0.0048 - accuracy: 0.9404 - mse: 0.0048 - val_loss: 0.0080 - val_accuracy: 0.8821 - val_mse: 0.0080
# Epoch 228/250
# 9600/9600 - 1s - loss: 0.0047 - accuracy: 0.9456 - mse: 0.0047 - val_loss: 0.0059 - val_accuracy: 0.9258 - val_mse: 0.0059
# Epoch 229/250
# 9600/9600 - 1s - loss: 0.0039 - accuracy: 0.9426 - mse: 0.0039 - val_loss: 0.0053 - val_accuracy: 0.9475 - val_mse: 0.0053
# Epoch 230/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9460 - mse: 0.0053 - val_loss: 0.0074 - val_accuracy: 0.8500 - val_mse: 0.0074
# Epoch 231/250
# 9600/9600 - 1s - loss: 0.0053 - accuracy: 0.9200 - mse: 0.0053 - val_loss: 0.0057 - val_accuracy: 0.9321 - val_mse: 0.0057
# Epoch 232/250
# 9600/9600 - 1s - loss: 0.0039 - accuracy: 0.9431 - mse: 0.0039 - val_loss: 0.0083 - val_accuracy: 0.8467 - val_mse: 0.0083
# Epoch 233/250
# 9600/9600 - 1s - loss: 0.0056 - accuracy: 0.9337 - mse: 0.0056 - val_loss: 0.0076 - val_accuracy: 0.9279 - val_mse: 0.0076
# Epoch 234/250
# 9600/9600 - 1s - loss: 0.0052 - accuracy: 0.9339 - mse: 0.0052 - val_loss: 0.0070 - val_accuracy: 0.9183 - val_mse: 0.0070
# Epoch 235/250
# 9600/9600 - 1s - loss: 0.0066 - accuracy: 0.9308 - mse: 0.0066 - val_loss: 0.0104 - val_accuracy: 0.8963 - val_mse: 0.0104
# Epoch 236/250
# 9600/9600 - 1s - loss: 0.0062 - accuracy: 0.9283 - mse: 0.0062 - val_loss: 0.0054 - val_accuracy: 0.9388 - val_mse: 0.0054
# Epoch 237/250
# 9600/9600 - 1s - loss: 0.0038 - accuracy: 0.9516 - mse: 0.0038 - val_loss: 0.0083 - val_accuracy: 0.8900 - val_mse: 0.0083
# Epoch 238/250
# 9600/9600 - 1s - loss: 0.0048 - accuracy: 0.9456 - mse: 0.0048 - val_loss: 0.0045 - val_accuracy: 0.9304 - val_mse: 0.0045
# Epoch 239/250
# 9600/9600 - 1s - loss: 0.0041 - accuracy: 0.9453 - mse: 0.0041 - val_loss: 0.0047 - val_accuracy: 0.9438 - val_mse: 0.0047
# Epoch 240/250
# 9600/9600 - 1s - loss: 0.0042 - accuracy: 0.9467 - mse: 0.0042 - val_loss: 0.0050 - val_accuracy: 0.9329 - val_mse: 0.0050
# Epoch 241/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9413 - mse: 0.0043 - val_loss: 0.0108 - val_accuracy: 0.9087 - val_mse: 0.0108
# Epoch 242/250
# 9600/9600 - 1s - loss: 0.0052 - accuracy: 0.9491 - mse: 0.0052 - val_loss: 0.0089 - val_accuracy: 0.9492 - val_mse: 0.0089
# Epoch 243/250
# 9600/9600 - 1s - loss: 0.0051 - accuracy: 0.9399 - mse: 0.0051 - val_loss: 0.0105 - val_accuracy: 0.9162 - val_mse: 0.0105
# Epoch 244/250
# 9600/9600 - 1s - loss: 0.0058 - accuracy: 0.9377 - mse: 0.0058 - val_loss: 0.0119 - val_accuracy: 0.8858 - val_mse: 0.0119
# Epoch 245/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9448 - mse: 0.0043 - val_loss: 0.0191 - val_accuracy: 0.9038 - val_mse: 0.0191
# Epoch 246/250
# 9600/9600 - 1s - loss: 0.0043 - accuracy: 0.9401 - mse: 0.0043 - val_loss: 0.0179 - val_accuracy: 0.8858 - val_mse: 0.0179
# Epoch 247/250
# 9600/9600 - 1s - loss: 0.0037 - accuracy: 0.9474 - mse: 0.0037 - val_loss: 0.0136 - val_accuracy: 0.8933 - val_mse: 0.0136
# Epoch 248/250
# 9600/9600 - 1s - loss: 0.0038 - accuracy: 0.9468 - mse: 0.0038 - val_loss: 0.0174 - val_accuracy: 0.9021 - val_mse: 0.0174
# Epoch 249/250
# 9600/9600 - 1s - loss: 0.0037 - accuracy: 0.9354 - mse: 0.0037 - val_loss: 0.0105 - val_accuracy: 0.8883 - val_mse: 0.0105
# Epoch 250/250
# 9600/9600 - 1s - loss: 0.0057 - accuracy: 0.9390 - mse: 0.0057 - val_loss: 0.0067 - val_accuracy: 0.9021 - val_mse: 0.0067

# %%
score = model.evaluate(X_test_scl , Y_test_scl , batch_size = 1000 , verbose = 0)
print('score:',score)
print('Accuracy:',score[1]*100,'%')
# Out:
# score: [0.03909909273271849, 0.8272796, 0.039099094]
# Accuracy: 82.72796273231506 %

# %%
Y_predict_scl = model.predict(X_test_scl)
Y_predict = Y_predict_scl * scaler_Y_train.scale_ + scaler_Y_train.mean_

# %%
print(history.params)
# Out:
# {'batch_size': 1000, 'epochs': 250, 'steps': 10, 'samples': 9600, 'verbose': 0, 'do_validation': True, 'metrics': ['loss', 'accuracy', 'mse', 'val_loss', 'val_accuracy', 'val_mse']}

# %%
plt.figure(dpi = 150)
plt.title('Train & Validation Accuracy')
plt.plot(history.history['accuracy'],label = 'Train_Accuracy')
plt.plot(history.history['val_accuracy'],label = 'Validation_Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(0,1)
#plt.savefig('Accuracy.png', dpi = 150)
# Out:
# (0.0, 1.0)

# %%
plt.figure(dpi = 150)
plt.title('Train & Validation MSE')
plt.plot(history.history['mse'],label = 'Train')
plt.plot(history.history['val_mse'],label = 'Validation')
plt.xlabel('Epoch')
plt.ylabel('Mean Square Error')
plt.legend()
#plt.savefig('MSE', dpi = 150)

# %%
Y_test_reshape = np.reshape(Y_test[:,0],(3937,))
Y_predict_reshape = np.reshape(Y_predict[:,0],(3937,))

min = 0.5
max = 5.5

plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,0],Y_predict[:,0],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real RR')
plt.ylabel('Predict RR')
plt.savefig('RR.png', dpi = 150)

R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])
# Out:
# R_Pearson =  0.9856118428261527

# %%
Y_test_reshape = np.reshape(Y_test[:,1],(3937,))
Y_predict_reshape = np.reshape(Y_predict[:,1],(3937,))

min = 99.5
max = 102.5

plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,1],Y_predict[:,1],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real B')
plt.ylabel('Predict B')
plt.savefig('B.png', dpi = 150)

R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])
# Out:
# R_Pearson =  0.9952688201196036

# %%
Y_test_reshape = np.reshape(Y_test[:,2],(3937,))
Y_predict_reshape = np.reshape(Y_predict[:,2],(3937,))

min = 1000
max = 6500

plt.figure(dpi = 150)
plt.xlim(min,max)
plt.ylim(min,max)
plt.scatter(Y_test[:,2],Y_predict[:,2],marker = '+')
plt.plot([min,max],[min,max],'black',linewidth = 1)
plt.xlabel('Real QR')
plt.ylabel('Predict QR')
plt.savefig('QR.png', dpi = 150)

R_Pearson = stats.pearsonr(Y_test_reshape , Y_predict_reshape)
print('R_Pearson = ', R_Pearson[0])
# Out:
# R_Pearson =  0.9947762173045702
